# %%
from PIL import Image

# %%
img=Image.open("giraffe.png")

# %%
print("Height:",img.height)
print("Width:",img.width)
img.show()
# Out:
# Height: 380
# Width: 740

# %%
import matplotlib.pyplot as plt

# %%
imgplot = plt.imshow(img)
plt.show()

# %%
import numpy as np

# %%
from skimage import data, io, filters

image = data.coins()
edges = filters.sobel(image)
io.imshow(edges)
io.show()

# %%
rows=512
cols=512

# %%
im=open('barbara_gray.raw')
print(im)
# Out:
# <_io.TextIOWrapper name='barbara_gray.raw' mode='r' encoding='cp1252'>

# %%
barbara = np.fromfile(im, dtype = np.uint8, count = rows*cols)

# %%
barbara.shape = (barbara.size//cols, cols)

# %%
barbara
# Out:
# array([[220, 229, 230, ..., 107, 106,  91],
#        [206, 228, 229, ...,  94,  97,  97],
#        [212, 227, 226, ...,  84,  97, 100],
#        ...,
#        [ 75,  62,  72, ...,  34,  43,  30],
#        [ 34,  50,  60, ...,  35,  29,  37],
#        [ 49,  47,  62, ...,  43,  30,  29]], dtype=uint8)

# %%
barbara.astype('int8').tofile('modifiedImage.raw')

# %%
im.close()
